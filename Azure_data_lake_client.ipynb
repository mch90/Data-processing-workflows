# %%
# !pip install azure-storage-file-datalake --pre
# Out:
# ...
#   Using cached msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# ...

# %%
# !pip install azure-datalake-store

# %%
from azure.storage.filedatalake import DataLakeServiceClient

service = DataLakeServiceClient(account_url="https://wsaone.dfs.core.windows.net/", credential='fcf056a8-704c-41dd-8740-4aa5e13ad0d4')

# %%
service

# %%
from azure.datalake.store import core, lib

# Define the parameters needed to authenticate using client secret 
token = lib.auth(tenant_id = '5efd6741-9f23-426d-8e2e-287e92d083ba',
                 client_secret = 'x5c7Q~vbkQ7szZKKtFmlxXQPu8ib_6TuK8MFB',
                 client_id = 'fcf056a8-704c-41dd-8740-4aa5e13ad0d4')

# Create a filesystem client object for the Azure Data Lake Store name (ADLS) 
adl = core.AzureDLFileSystem(token, store_name='ADLS Account Name')

# %%
adl.listdir()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9068/1889688671.py in <module>
# ----> 1 adl.listdir()
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\datalake\store\core.py in ls(self, path, detail, invalidate_cache)
#     166         """
#     167         path = AzureDLPath(path)
# --> 168         files = self._ls(path, invalidate_cache)
#     169         if not files:
#     170             # in this case we just invalidated the cache (if it was true), so no need to do it again
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\datalake\store\core.py in _ls(self, path, invalidate_cache, batch_size)
#     143
#     144         if key not in self.dirs:
# --> 145             self.dirs[key] = self._ls_batched(key, batch_size=batch_size)
#     146             for f in self.dirs[key]:
# ...

# %%
from azure.identity import ClientSecretCredential
token_credential = ClientSecretCredential(
    self.active_directory_tenant_id,
    self.active_directory_application_id,
    self.active_directory_application_secret,
   )
datalake_service_client = DataLakeServiceClient("https://wsaone.dfs.core.windows.net/".format(self.account_name),
                                                   credential=token_credential)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11820/2751745318.py in <module>
# ----> 1 from azure.identity import ClientSecretCredential
#       2 token_credential = ClientSecretCredential(
#       3     self.active_directory_tenant_id,
#       4     self.active_directory_application_id,
#       5     self.active_directory_application_secret,
#
# ModuleNotFoundError: No module named 'azure.identity'

# %%
def initialize_storage_account(storage_account_name, storage_account_key):
    
    try:  
        global service_client

        service_client = DataLakeServiceClient(account_url="https://wsaone.dfs.core.windows.net/".format(
            "https", storage_account_name), credential=storage_account_key)
    
    except Exception as e:
        print(e)

        

initialize_storage_account('https://wsaone.dfs.core.windows.net/', 'fcf056a8-704c-41dd-8740-4aa5e13ad0d4')

# %%
from azure.storage.filedatalake import DataLakeServiceClient
# install the following package 
# pip install azure-storage-file-datalake 

# Get the below details from your storage account
storage_account_name = "https://wsaone.dfs.core.windows.net/"
storage_account_key = "x5c7Q~vbkQ7szZKKtFmlxXQPu8ib_6TuK8MFB"
container_name = "sensor-archive"
directory_name = "Source/sensor"

service_client = DataLakeServiceClient(account_url="https://wsaone.dfs.core.windows.net/".format(
        "https", storage_account_name), credential=storage_account_key)

service_client

#file_system_client = service_client.get_file_system_client(file_system=container_name)
#dir_client = file_system_client.get_directory_client(directory_name)
#dir_client.create_directory()
#data = """
#        Sample data for testing. 
#        This is a multiline text for testing the ADLS Gen2 file system operations.
#"""

#file_client = dir_client.create_file("sampledata.txt")
#file_client.append_data(data, 0, len(data))
#file_client.flush_data(len(data))

# %%
def list_directory_contents():
    try:
        
        file_system_client = service_client.get_file_system_client(file_system="my-file-system")

        paths = file_system_client.get_paths(path="Source")

        for path in paths:
            print(path.name + '\n')

    except Exception as e:
     print(e)

list_directory_contents()
# Out:
# (AuthorizationPermissionMismatch) This request is not authorized to perform this operation using this permission.
# RequestId:d6fe6b2c-c01f-0056-4482-0c2e98000000
# Time:2022-01-18T15:47:12.6130530Z
# Code: AuthorizationPermissionMismatch
# Message: This request is not authorized to perform this operation using this permission.
# RequestId:d6fe6b2c-c01f-0056-4482-0c2e98000000
# Time:2022-01-18T15:47:12.6130530Z

# %%
service_client.get_file_system_client
paths = file_system_client.get_paths

# %%
# !pip install azure-mgmt
# Out:
# ^C
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Michal\.conda\envs\CogniPy\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Michal\\AppData\\Local\\Temp\\pip-install-wllfqjax\\azure-mgmt_98c0379ff9f749589b17a0cd495bea29\\setup.py'"'"'; __file__='"'"'C:\\Users\\Michal\\AppData\\Local\\Temp\\pip-install-wllfqjax\\azure-mgmt_98c0379ff9f749589b17a0cd495bea29\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Michal\AppData\Local\Temp\pip-pip-egg-info-2fkq31nw'
#        cwd: C:\Users\Michal\AppData\Local\Temp\pip-install-wllfqjax\azure-mgmt_98c0379ff9f749589b17a0cd495bea29\
#   Complete output (23 lines):
#   Traceback (most recent call last):
# ...

# %%
import pandas as pd
from azure.identity import InteractiveBrowserCredential
from azure.storage.filedatalake import DataLakeServiceClient
from io import BytesIO
from azure.identity import ClientSecretCredential

#credential = ClientSecretCredential(tenant_id, client_id, client_secret)

#new_temporary_access:
#"tenantId: ten sam
#clientId: b825bd1f-81a3-4cd7-9027-805d8fff7137
#secret: ys57Q~Q.dHUcxF8B.2if8p0FtEI6jkb1Y-HVN"



credential = ClientSecretCredential('5efd6741-9f23-426d-8e2e-287e92d083ba', 'b825bd1f-81a3-4cd7-9027-805d8fff7137', 'ys57Q~Q.dHUcxF8B.2if8p0FtEI6jkb1Y-HVN')

# Get the below details from your storage account
storage_account_name = "wsaone"
container_name = "sensor-archive"
directory_name = "Temperature/2022/01"

#will use Azure AD Integrated connection
service_client = DataLakeServiceClient(account_url="{}://{}.dfs.core.windows.net".format(
        "https", storage_account_name), credential=credential)  
file_system_client = service_client.get_file_system_client(file_system=container_name)
dir_client = file_system_client.get_directory_client(directory_name)

file_name = "3e109af8-a253-498b-8108-9be323ccc5cd-1.0.csv"
file_client = dir_client.get_file_client(file_name)

# %%
download = file_client.download_file()
downloaded_bytes = download.readall()

#Read sensor data from dolne wrzeciono
#df_dane_z_testu_01_02 = pd.read_csv('Klient_B_zopisem_modified_for_processing_only_values_v2.csv',  sep=';', encoding='latin1',parse_dates=['Category'])
#df_dane_z_testu_01_02.head()
#pd.read_csv('opisy_stanow.csv',  sep=';', encoding='latin1',)

data = BytesIO(downloaded_bytes)
csvfile = pd.read_csv(data,sep=';',encoding='latin1')

csvfile.count()
# Out:
# timestamp    260389
# value        260389
# dtype: int64

# %%
csvfile
# Out:
#             timestamp      value
# 0       1641188329000  21.033081
# 1       1641188332000  21.087521
# 2       1641188334000  21.065228
# 3       1641188336000  21.155411
# 4       1641188339000  21.122753
# ...               ...        ...
# 260384  1642124397000  38.499996
# 260385  1642124399000  38.499996
# 260386  1642124401000  38.499996
# 260387  1642124404000  38.499996
# 260388  1642124406000  38.499996
#
# [260389 rows x 2 columns]

# %%
# Convert timestamp to readable format (original timestamp is in javascript 13-digit format miliseconds)
 
string_date_rng = [[datetime.fromtimestamp(int(x)/1000).strftime("%Y-%m-%d %H:%M:%S")] for x in csvfile.timestamp]

# %%
print(string_date_rng[0])
print(string_date_rng[260388])
# Out:
# ['2022-01-03 06:38:49']
# ['2022-01-14 02:40:06']

# %%
csvfile['timestamp']=pd.Series(string_date_rng)

# %%
144.44444444444446/24
# Out:
# 6.018518518518519

# %%
timestamp = csvfile.timestamp[260388]
your_dt = datetime.fromtimestamp(int(timestamp)/1000)  # using the local timezone
print(your_dt.strftime("%Y-%m-%d %H:%M:%S"))  # 2018-04-07 20:48:08, YMMV
# Out:
# 2022-01-14 02:40:06

# %%
from azure.storage.filedatalake import DataLakeFileClient

file = DataLakeFileClient.from_connection_string('https://wsaone.dfs.core.windows.net/',credential=credential,
                                                 file_system_name=container_name, file_path="Source")

with open("./1641426427000-1.0.csv", "wb") as my_file:
    download = file.download_file()
    download.readinto(my_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11180/837911633.py in <module>
#       1 from azure.storage.filedatalake import DataLakeFileClient
#       2
# ----> 3 file = DataLakeFileClient.from_connection_string('https://wsaone.dfs.core.windows.net/',credential=credential,
#       4                                                  file_system_name=container_name, file_path="Source")
#       5
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\storage\filedatalake\_data_lake_file_client.py in from_connection_string(cls, conn_str, file_system_name, file_path, credential, **kwargs)
#     107         :rtype ~azure.storage.filedatalake.DataLakeFileClient
#     108         """
# --> 109         account_url, _, credential = parse_connection_str(conn_str, credential, 'dfs')
#     110         return cls(
# ...

# %%
string_date_rng
# Out:
# [['2022-01-03 06:38:49'],
#  ['2022-01-03 06:38:52'],
#  ['2022-01-03 06:38:54'],
#  ['2022-01-03 06:38:56'],
#  ['2022-01-03 06:38:59'],
#  ['2022-01-03 06:39:01'],
#  ['2022-01-03 06:39:03'],
#  ['2022-01-03 06:39:06'],
#  ['2022-01-03 06:39:08'],
#  ['2022-01-03 06:39:11'],
#  ['2022-01-03 06:39:13'],
#  ['2022-01-03 06:39:16'],
#  ['2022-01-03 06:39:18'],
#  ['2022-01-03 06:39:20'],
#  ['2022-01-03 06:39:22'],
#  ['2022-01-03 06:39:24'],
#  ['2022-01-03 06:39:26'],
#  ['2022-01-03 06:39:29'],
#  ['2022-01-03 06:39:31'],
#  ['2022-01-03 06:39:33'],
#  ['2022-01-03 06:39:35'],
#  ['2022-01-03 06:39:38'],
#  ['2022-01-03 06:39:40'],
#  ['2022-01-03 06:39:42'],
#  ['2022-01-03 06:39:44'],
#  ['2022-01-03 06:39:47'],
#  ['2022-01-03 06:39:49'],
#  ['2022-01-03 06:39:51'],
#  ['2022-01-03 06:39:53'],
#  ['2022-01-03 06:39:55'],
#  ['2022-01-03 06:39:57'],
#  ['2022-01-03 06:39:59'],
#  ['2022-01-03 06:40:02'],
#  ['2022-01-03 06:40:04'],
#  ['2022-01-03 06:40:06'],
# ...

# %%
file = DataLakeFileClient.from_connection_string(credential,file_system_name="sensor-archive", file_path="Source")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11180/2961892040.py in <module>
# ----> 1 file = DataLakeFileClient.from_connection_string(credential,file_system_name="sensor-archive", file_path="Source")
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\storage\filedatalake\_data_lake_file_client.py in from_connection_string(cls, conn_str, file_system_name, file_path, credential, **kwargs)
#     107         :rtype ~azure.storage.filedatalake.DataLakeFileClient
#     108         """
# --> 109         account_url, _, credential = parse_connection_str(conn_str, credential, 'dfs')
#     110         return cls(
#     111             account_url, file_system_name=file_system_name, file_path=file_path,
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\storage\filedatalake\_shared\base_client.py in parse_connection_str(conn_str, credential, service)
# ...

# %%
path_list = file_system_client.get_paths()
for path in path_list:
    print(path.name + '\n')
# Out:
# Accelerometer
#
# Accelerometer/2022
#
# Accelerometer/2022/01
#
# Accelerometer/2022/01/3e109af8-a253-498b-8108-9be323ccc5cd-1.0.csv
#
# Accelerometer/2022/01/5318ce68-ecb6-4fe7-a074-f1deb33567e3-1.0.csv
#
# Sensor
#
# Sensor/3e109af8-a253-498b-8108-9be323ccc5cd-1.0.csv
#
# Sensor/45c25245-6ca7-498b-bfb5-2df2a4ef8ae4-1.0.csv
#
# Sensor/5318ce68-ecb6-4fe7-a074-f1deb33567e3-1.0.csv
#
# Sensor/59aec389-a47d-4c76-89a4-9a586e8699b6-1.0.csv
#
# Sensor/9f05c6ad-30a0-4cd7-ab3a-34aaaa135cc0-1.0.csv
#
# Source
#
# Source/1642361147-1.0.csv
#
# Temperature
#
# Temperature/2022
#
# Temperature/2022/01
#
# Temperature/2022/01/3e109af8-a253-498b-8108-9be323ccc5cd-1.0.csv
#
# Temperature/2022/01/5318ce68-ecb6-4fe7-a074-f1deb33567e3-1.0.csv

# %%
file_system_client.
# Out:
# <bound method FileSystemClient._get_root_directory_client of <azure.storage.filedatalake._file_system_client.FileSystemClient object at 0x00000249E64B9130>>

# %%
def list_directory_contents():
    try:
        
        file_system_client = service_client.get_file_system_client(file_system=container_name)

        paths = file_system_client.get_paths(path="Sensor")

        for path in paths:
            print(path.name + '\n')

    except Exception as e:
     print(e)

# %%
list_directory_contents()
# Out:
# Sensor/3e109af8-a253-498b-8108-9be323ccc5cd-1.0.csv
#
# Sensor/45c25245-6ca7-498b-bfb5-2df2a4ef8ae4-1.0.csv
#
# Sensor/5318ce68-ecb6-4fe7-a074-f1deb33567e3-1.0.csv
#
# Sensor/59aec389-a47d-4c76-89a4-9a586e8699b6-1.0.csv
#
# Sensor/9f05c6ad-30a0-4cd7-ab3a-34aaaa135cc0-1.0.csv

# %%
#local_file = open("C:\\file-to-download.txt",'wb')

file_client = dir_client.get_file_client("1641426427000-1.0.csv")

download = file_client.download_file()

downloaded_bytes = download.readall()

#local_file.write(downloaded_bytes)

#local_file.close()
# Out:
# ---------------------------------------------------------------------------
# HttpResponseError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9068/2066825489.py in <module>
#       3 file_client = dir_client.get_file_client("1641426427000-1.0.csv")
#       4
# ----> 5 download = file_client.download_file()
#       6
#       7 downloaded_bytes = download.readall()
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\storage\filedatalake\_data_lake_file_client.py in download_file(self, offset, length, **kwargs)
#     608                 :caption: Return the downloaded data.
#     609         """
# --> 610         downloader = self._blob_client.download_blob(offset=offset, length=length, **kwargs)
#     611         return StorageStreamDownloader(downloader)
#     612
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\core\tracing\decorator.py in wrapper_use_tracer(*args, **kwargs)
# ...

# %%
from azure.storage.blob import BlobServiceClient
import os

source_key = 'Key'
source_account_name = 'Account Name'
block_blob_service = BlobServiceClient(
    account_url=f'https://{source_account_name}.blob.core.windows.net/', credential=credential)
source_container_client = block_blob_service.get_container_client(
    'Container name')
result=[]
allfolders=[]
generator =source_container_client.list_blobs("account")

for file in source_container_client.walk_blobs('account/', delimiter='/'):
    print(file.name)
    text=file.name
    result.append(text)
for data in result:
    
    allfolders.append(data.replace("account/",""))
print(allfolders)
for res in allfolders:
    print(res)

# %%
for file_path in azure_all_files:
    file_client = parent_directory_client.get_file_client(file_path)
    download = file_client.download_file()
    downloaded_bytes = download.readall()

    target_path = os.path.join(self.local_data_directory, file_path)
    with open(target_path, 'wb') as file:
        file.write(downloaded_bytes)

# %%
file_system_client.

# %%
file_client.download_file('uuid1-1.0.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9068/1680787638.py in <module>
# ----> 1 file_client.download_file('uuid1-1.0.csv')
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\storage\filedatalake\_data_lake_file_client.py in download_file(self, offset, length, **kwargs)
#     608                 :caption: Return the downloaded data.
#     609         """
# --> 610         downloader = self._blob_client.download_blob(offset=offset, length=length, **kwargs)
#     611         return StorageStreamDownloader(downloader)
#     612
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\core\tracing\decorator.py in wrapper_use_tracer(*args, **kwargs)
#      81             span_impl_type = settings.tracing_implementation()
#      82             if span_impl_type is None:
# ---> 83                 return func(*args, **kwargs)
#      84
# ...

# %%
download = file_client.download_file(Source/uuid1-1.0.csv)
#downloaded_bytes = download.readall()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9068/1874222872.py in <module>
# ----> 1 download = file_client.download_file('Source/uuid1-1.0.csv')
#       2 #downloaded_bytes = download.readall()
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\storage\filedatalake\_data_lake_file_client.py in download_file(self, offset, length, **kwargs)
#     608                 :caption: Return the downloaded data.
#     609         """
# --> 610         downloader = self._blob_client.download_blob(offset=offset, length=length, **kwargs)
#     611         return StorageStreamDownloader(downloader)
#     612
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\core\tracing\decorator.py in wrapper_use_tracer(*args, **kwargs)
#      81             span_impl_type = settings.tracing_implementation()
#      82             if span_impl_type is None:
# ...

# %%
file_name = "uuid1-1.0.csv"
file_client = dir_client.get_file_client(file_name)

#download = file_client.download_file()
#downloaded_bytes = download.readall()

# %%
dir_client = file_system_client.get_directory_client(directory_name)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9068/2496592213.py in <module>
# ----> 1 for path in dir_client:
#       2     print(path.name + '\n')
#
# TypeError: 'DataLakeDirectoryClient' object is not iterable

# %%
dir_client
# Out:
# <iterator object azure.core.paging.ItemPaged at 0x1bb0a3b5c10>

# %%
# Show Azure subscription information

import os
from azure.identity import InteractiveBrowserCredential
from azure.mgmt.resource import SubscriptionClient

credential = InteractiveBrowserCredential()
subscription_client = SubscriptionClient(credential)

subscription = next(subscription_client.subscriptions.list())
#print(subscription.subscription_id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8792/3356250880.py in <module>
#       8 subscription_client = SubscriptionClient(credential)
#       9
# ---> 10 subscription = next(subscription_client.subscriptions.list())
#      11 #print(subscription.subscription_id)
#
# ~\.conda\envs\CogniPy\lib\site-packages\msrest\paging.py in __next__(self)
#     141             return response
#     142         else:
# --> 143             self.advance_page()
#     144             return self.__next__()
#     145
#
# ~\.conda\envs\CogniPy\lib\site-packages\msrest\paging.py in advance_page(self)
#     127             raise StopIteration("End of paging")
#     128         self._current_page_iter_index = 0
# --> 129         self._response = self._get_next(self.next_link)
#     130         self._derserializer(self, self._response)
# ...

# %%
# !pip install msgraph-core

# %%
from azure.storage.blob import BlobServiceClient
from azure.identity import InteractiveBrowserCredential, DeviceCodeCredential, ClientSecretCredential

credential = DeviceCodeCredential(authority="login.microsoftonline.com", tenant_id="5efd6741-9f23-426d-8e2e-287e92d083ba", client_id="fcf056a8-704c-41dd-8740-4aa5e13ad0d4")

blobber = BlobServiceClient(account_url="https://wsaone.dfs.core.windows.net/", credential=credential)

blobs = blobber.list_containers()
for b in blobs:
    print(b)
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CL4RQ82C7 to authenticate.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8792/1457189379.py in <module>
#       7
#       8 blobs = blobber.list_containers()
# ----> 9 for b in blobs:
#      10     print(b)
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\core\paging.py in __next__(self)
#     127         if self._page_iterator is None:
#     128             self._page_iterator = itertools.chain.from_iterable(self.by_page())
# --> 129         return next(self._page_iterator)
#     130
#     131     next = __next__  # Python 2 compatibility.
#
# ~\.conda\envs\CogniPy\lib\site-packages\azure\core\paging.py in __next__(self)
#      74             raise StopIteration("End of paging")
#      75         try:
# ...

# %%
from azure.identity import InteractiveBrowserCredential
from msgraph.core import GraphClient
import uuid
import json

browser_credential = InteractiveBrowserCredential(client_id='fcf056a8-704c-41dd-8740-4aa5e13ad0d4')
graph_client = GraphClient(credential=browser_credential)
scopes = ['Application.ReadWrite.All', 'User.Read']

# %%
broswer_credential = InteractiveBrowserCredential(client_id='7537790f-b619-4d30-a804-1c6b8b7f1523')
graph_client = GraphClient(credential=broswer_credential)
scopes = ['Application.ReadWrite.All', 'User.Read']


# %%


result = graph_client.get('/organization')
tenantJson = json.dumps(result.json())
tenant = json.loads(tenantJson)

print(f"Tenant Id: {tenant['id']}")
